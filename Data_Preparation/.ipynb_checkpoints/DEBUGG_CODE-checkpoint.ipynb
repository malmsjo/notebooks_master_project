# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import glob 
import os
from os import *
import re
import imutils
from skimage.feature import peak_local_max
from skimage.morphology import watershed
from scipy import ndimage
import collections
import tqdm
import shutil
from sklearn.model_selection import train_test_split

# %%
def return_count(x):
    name_wel = []
    for i in x:
        name_wel.append(i.split('_')[0])

    z = list(set(name_wel))
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in x:
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def creat_label(y, indirizo):
    labels = []
    for ix, _ in enumerate(y):
        labels.append([[y[ix][0],y[ix][1]]] * y[ix][2])
    
    ler = [i for sub in labels for i in sub ]

    df = pd.DataFrame(ler, columns = ['Type', 'Category'])
    df = df.sort_values(by=['Type'])
    df.to_csv(indirizo, sep=',',index=False)
    return 'Done'

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
list_compound = ['LEBETALOL','CONTROLL','MEPHENTEREMINE','OXYMETAZOLINE']

for l_compound in list_compound:

    pa = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T60_T_97/{}_cropped/'.format(l_compound)


    name = []
    for d, di, file in os.walk(pa):
        for i in file:
            name.append(i)


    name =sorted(name)


    well = []
    for i in name:
        well.append(i.split('_id')[0])

    well_name = list(set(well))

    well_name = sorted(well_name)

    l = []
    for ix, _ in enumerate(well_name):
        n = []
        for i in name:
            if well_name[ix] in i:
                n.append(i)
        l.append(n)


    tot_list = []

    for ix, i in tqdm.tqdm(enumerate(l)):


        id_n = []
        for j in l[ix]:
            id_n.append(j.split('_time')[0].split('_id_')[1])

        id_name = list(set(id_n))

        l1 = []
        for ixd, _ in enumerate(id_name):
            n1 = []
            for na in l[ix]:
                if 'id_{}_time'.format(id_name[ixd]) in na:
                    n1.append(na)
            l1.append(n1)

        tot_list.append(l1)




    tra = []
    tes = []
    val = []

    for ie in tqdm.tqdm((range(len(tot_list)))):

        f_list = tot_list[ie]

        li = list(range((len(f_list))))

        f, s = train_test_split(li, test_size=0.2, random_state=100)
        f1, v = train_test_split(f, test_size=0.2, random_state=100)

        for i in f1:

            tra.append(f_list[i])

        for j in s:
            tes.append(f_list[j])

        for v1 in v:
            val.append(f_list[v1])

    train = []
    test = []
    validation = []


    train = [i for sub in tra for i in sub]

    test = [i for sub in tes for i in sub]

    validation = [i for sub in val for i in sub]
# Out:
# 8it [00:00, 35.96it/s]
# 100%|██████████| 8/8 [00:00<00:00, 1130.96it/s]
# 8it [00:00, 16.79it/s]
# 100%|██████████| 8/8 [00:00<00:00, 609.11it/s]
# 8it [00:00, 28.35it/s]
# 100%|██████████| 8/8 [00:00<00:00, 694.32it/s]
# 8it [00:00, 26.55it/s]
# 100%|██████████| 8/8 [00:00<00:00, 938.38it/s]

# %%
img = []
for i in glob.glob( '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T60_T_97/CONTROLL_cropped/*.tiff'):
    if 'B3-4_id_15_' in i:
        im = cv2.imread(i)
        img.append(im)

# %%
len(img)
# Out:
# 35

# %%
fig = plt.figure(figsize=(20, 20))


for i in range(30):
    ax = fig.add_subplot(3,10,i+1),plt.imshow(img[i],'gray')
    #plt.title(titles[i], color='white')
    plt.xticks([]),plt.yticks([])
plt.show()
