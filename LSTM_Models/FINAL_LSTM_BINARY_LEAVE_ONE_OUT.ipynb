# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import LSTM, Bidirectional, Embedding
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from sklearn.metrics import f1_score

from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from sklearn.utils import class_weight
from tensorflow.keras.applications.vgg16 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/img1.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.savefig('/home/jovyan/img2.png')
    plt.show()
   
    
    return fig

# %%
def loadImages(path_data, path_labels):
    

    feat_list = []


    for filename in sorted(glob.glob(path_data), key=natural_keys): 
        feat_list.append(np.load(filename))

    x_orig = np.reshape(feat_list, (len(feat_list),32, 64))

    path = path_labels     
    labels = pd.read_csv(path, usecols=["Type", "Category"],
                       sep="," )
    y_orig = np.array(labels['Category'])

    return x_orig, y_orig

# %%
p_feat = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FINAL_LSTM_LEAVE_ONE_OUT/HRH_CONTROL/ket/'

train_data = p_feat + 'features_train/*.npy'
train_lab= p_feat + 'lstm_train.csv'

val_data = p_feat + 'features_validation/*.npy'
val_lab = p_feat + 'lstm_validation.csv'


test_data= p_feat + 'features_test/*.npy'
test_lab= p_feat + 'lstm_test.csv'

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)

# %%
x_train, y_train = loadImages(train_data, train_lab)
x_train.shape, y_train.shape
# Out:
# ((1061, 32, 64), (1061,))

# %%
x_val, y_val = loadImages(val_data, val_lab)
x_val.shape, y_val.shape
# Out:
# ((359, 32, 64), (359,))

# %%
x_test, y_test = loadImages(test_data, test_lab)
x_test.shape, y_test.shape
# Out:
# ((233, 32, 64), (233,))

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 694, 1: 367}

# %%
weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)
print('weights = ' + str(weights))
# Out:
# weights = [0.76440922 1.44550409]

# %%
m = Sequential()
m.add(LSTM(64, input_shape = (x_train.shape[1],x_train.shape[2])))
m.add(Dropout(0.2))
m.add(Dense(1, activation='sigmoid'))
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                33024
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 33,089
# Trainable params: 33,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(lr=1e-4)

m.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

# %%
epochs = 300

m4_h = m.fit(x_train,y_train,
                 
                 callbacks = [es],
                
                epochs=epochs,
                validation_data = (x_val,y_val), 
                
                class_weight = weights)
# Out:
# Train on 1061 samples, validate on 359 samples
# Epoch 1/300
# 1061/1061 [==============================] - 4s 3ms/sample - loss: 0.6476 - accuracy: 0.6503 - val_loss: 0.6686 - val_accuracy: 0.5822
# Epoch 2/300
# 1061/1061 [==============================] - 0s 253us/sample - loss: 0.6176 - accuracy: 0.6616 - val_loss: 0.6521 - val_accuracy: 0.5905
# Epoch 3/300
# 1061/1061 [==============================] - 0s 264us/sample - loss: 0.6017 - accuracy: 0.6805 - val_loss: 0.6316 - val_accuracy: 0.6184
# Epoch 4/300
# 1061/1061 [==============================] - 0s 256us/sample - loss: 0.5808 - accuracy: 0.6852 - val_loss: 0.6119 - val_accuracy: 0.6462
# Epoch 5/300
# 1061/1061 [==============================] - 0s 252us/sample - loss: 0.5517 - accuracy: 0.7201 - val_loss: 0.5841 - val_accuracy: 0.6880
# Epoch 6/300
# 1061/1061 [==============================] - 0s 236us/sample - loss: 0.5254 - accuracy: 0.7248 - val_loss: 0.5543 - val_accuracy: 0.7437
# Epoch 7/300
# 1061/1061 [==============================] - 0s 227us/sample - loss: 0.4926 - accuracy: 0.7653 - val_loss: 0.5310 - val_accuracy: 0.7604
# Epoch 8/300
# 1061/1061 [==============================] - 0s 249us/sample - loss: 0.4725 - accuracy: 0.7776 - val_loss: 0.5126 - val_accuracy: 0.7660
# Epoch 9/300
# 1061/1061 [==============================] - 0s 249us/sample - loss: 0.4624 - accuracy: 0.7936 - val_loss: 0.4887 - val_accuracy: 0.7716
# Epoch 10/300
# 1061/1061 [==============================] - 0s 237us/sample - loss: 0.4456 - accuracy: 0.8058 - val_loss: 0.4837 - val_accuracy: 0.7827
# Epoch 11/300
# 1061/1061 [==============================] - 0s 230us/sample - loss: 0.4343 - accuracy: 0.8115 - val_loss: 0.4726 - val_accuracy: 0.7967
# Epoch 12/300
# 1061/1061 [==============================] - 0s 266us/sample - loss: 0.4179 - accuracy: 0.8153 - val_loss: 0.4787 - val_accuracy: 0.7883
# Epoch 13/300
# 1061/1061 [==============================] - 0s 265us/sample - loss: 0.4155 - accuracy: 0.8228 - val_loss: 0.4490 - val_accuracy: 0.8022
# Epoch 14/300
# 1061/1061 [==============================] - 0s 254us/sample - loss: 0.4055 - accuracy: 0.8209 - val_loss: 0.4440 - val_accuracy: 0.8078
# Epoch 15/300
# 1061/1061 [==============================] - 0s 257us/sample - loss: 0.3961 - accuracy: 0.8332 - val_loss: 0.4564 - val_accuracy: 0.8050
# Epoch 16/300
# 1061/1061 [==============================] - 0s 242us/sample - loss: 0.3872 - accuracy: 0.8435 - val_loss: 0.4488 - val_accuracy: 0.8022
# Epoch 17/300
# 1061/1061 [==============================] - 0s 235us/sample - loss: 0.3762 - accuracy: 0.8520 - val_loss: 0.4307 - val_accuracy: 0.8106
# Epoch 18/300
# 1061/1061 [==============================] - 0s 278us/sample - loss: 0.3722 - accuracy: 0.8577 - val_loss: 0.4449 - val_accuracy: 0.8050
# Epoch 19/300
# 1061/1061 [==============================] - 0s 267us/sample - loss: 0.3711 - accuracy: 0.8464 - val_loss: 0.4081 - val_accuracy: 0.8189
# Epoch 20/300
# 1061/1061 [==============================] - 0s 242us/sample - loss: 0.3554 - accuracy: 0.8643 - val_loss: 0.4126 - val_accuracy: 0.8217
# Epoch 21/300
# 1061/1061 [==============================] - 0s 240us/sample - loss: 0.3550 - accuracy: 0.8605 - val_loss: 0.4147 - val_accuracy: 0.8134
# Epoch 22/300
# 1061/1061 [==============================] - 0s 255us/sample - loss: 0.3459 - accuracy: 0.8662 - val_loss: 0.4051 - val_accuracy: 0.8217
# Epoch 23/300
# 1061/1061 [==============================] - 0s 208us/sample - loss: 0.3401 - accuracy: 0.8652 - val_loss: 0.4115 - val_accuracy: 0.8217
# Epoch 24/300
# 1061/1061 [==============================] - 0s 241us/sample - loss: 0.3271 - accuracy: 0.8718 - val_loss: 0.4098 - val_accuracy: 0.8273
# Epoch 25/300
# 1061/1061 [==============================] - 0s 258us/sample - loss: 0.3207 - accuracy: 0.8812 - val_loss: 0.3903 - val_accuracy: 0.8301
# Epoch 26/300
# 1061/1061 [==============================] - 0s 254us/sample - loss: 0.3170 - accuracy: 0.8794 - val_loss: 0.4043 - val_accuracy: 0.8245
# Epoch 27/300
# 1061/1061 [==============================] - 0s 254us/sample - loss: 0.3095 - accuracy: 0.8850 - val_loss: 0.3949 - val_accuracy: 0.8329
# Epoch 28/300
# 1061/1061 [==============================] - 0s 242us/sample - loss: 0.2988 - accuracy: 0.8897 - val_loss: 0.3927 - val_accuracy: 0.8273
# Epoch 00028: early stopping

# %%
plot_history(m4_h, 'first')

# %%
scores = m.evaluate(x_test, y_test)
print("\n%s: %.2f%%" % (m.metrics_names[1], scores[1]*100))
# Out:
# 233/233 [==============================] - 0s 120us/sample - loss: 0.5932 - accuracy: 0.7082
#
# accuracy: 70.82%

# %% [markdown]
# # For Binary Classification

# %%
test_preds = m.predict(x_test)

t= []
for i in (test_preds):
    if i > 0.5:
        t.append(1)
    else:
        t.append(0)

draw_confusion_matrix(y_test, t)
# Out:
# array([[165,  68],
#        [  0,   0]])

# %%
print(classification_report(y_test, t))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.42      0.59       200
#
#     accuracy                           0.42       200
#    macro avg       0.50      0.21      0.30       200
# weighted avg       1.00      0.42      0.59       200
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
