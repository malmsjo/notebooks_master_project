# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import glob
import os
from os import *
import re
import imutils
from skimage.feature import peak_local_max
from skimage.morphology import watershed
from scipy import ndimage
import collections
import random

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
image_list = []
    

for filename in sorted(glob.glob('/home/jovyan/DATA_MASTER_PROJECT/A549/train/*.tiff'), key=natural_keys): 
    im=cv2.imread(filename)
    imarray = np.array(im)
    gray_image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    image_list.append(gray_image)

# %%
i = random.choice(image_list)

# %%
plt.imshow(i)

# %%
tot_pix = []
for i in image_list:
    for _ in range(10000):
        x = int(np.random.choice(1023, 1, replace=False))
        y = int(np.random.choice(1023, 1, replace=False))
        s = i[x,y]
        tot_pix.append(s)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-935511f1c5a6> in <module>
#       3     for _ in range(10000):
#       4         x = int(np.random.choice(1023, 1, replace=False))
# ----> 5         y = int(np.random.choice(1023, 1, replace=False))
#       6         s = i[x,y]
#       7         tot_pix.append(s)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    2960     """
#    2961     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
# -> 2962                           keepdims=keepdims, initial=initial, where=where)
#    2963
#    2964
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
len(tot_pix)

# %%
plt.hist(tot_pix,256,[0,256]) 
plt.show()

# %%
image_list_2 = []
    

for filename in sorted(glob.glob('/home/jovyan/DATA_MASTER_PROJECT/A549/test/*.tiff'), key=natural_keys): 
    im=cv2.imread(filename)
    imarray = np.array(im)
    gray_image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    image_list_2.append(gray_image)

# %%
len(image_list_2)

# %%
tot_p = []
for i in image_list_2:
    for _ in range(10000):
        x = int(np.random.choice(1023, 1, replace=False))
        y = int(np.random.choice(1023, 1, replace=False))
        s = i[x,y]
        tot_p.append(s)
        
plt.hist(tot_p,256,[0,256]) 
plt.show()
