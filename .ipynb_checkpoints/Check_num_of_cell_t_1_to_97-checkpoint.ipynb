# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import glob
import os
import re
import imutils
from skimage.feature import peak_local_max
from skimage.morphology import watershed
from scipy import ndimage
import tqdm

# %%
def atoi(text):
   return int(text) if text.isdigit() else text
def natural_keys(text):
   return [atoi(c) for c in re.split('(\d+)', text)]

# %%
image_list = []
    

    for filename in sorted(glob.glob('/home/jovyan/DATA_MASTER_PROJECT/IMAGES_MASTER_PROJECT/count_cell/*.tiff'), key=natural_keys): 
        
        if 'B8' and 
        
        im=cv2.imread(filename)
        imarray = np.array(im)
        imarray = imarray.astype('float32')
        image_list.append(imarray)

# %%
path = '/mnt/holomonitor-pvc/project/gpcr/Storage/P010720_2/'

time = []


n = list(range(1,5))
li = ['B8','B2','E8','C5']
time_point = [' 1','97']

for dirname, dirnames,filenames in os.walk(path):
    
    for filename in sorted(filenames, key = natural_keys):
        
        for index in n:
            for le in li:
                for t in time_point:
                    if '{}-{}'.format(le,index) in filename and  '{}.tiff'.format(t) in filename:
                        time.append(filename)

# %%
time_1 = []
time_97 = []

for i in sorted(time, key=natural_keys):
    if '{}'.format('97') in i:
        time_97.append(i)
    else:
        time_1.append(i)

# %%
time_1
# Out:
# ['Well B2-1 1.tiff',
#  'Well B2-2 1.tiff',
#  'Well B2-3 1.tiff',
#  'Well B2-4 1.tiff',
#  'Well B8-1 1.tiff',
#  'Well B8-2 1.tiff',
#  'Well B8-3 1.tiff',
#  'Well B8-4 1.tiff',
#  'Well C5-1 1.tiff',
#  'Well C5-2 1.tiff',
#  'Well C5-3 1.tiff',
#  'Well C5-4 1.tiff',
#  'Well E8-1 1.tiff',
#  'Well E8-2 1.tiff',
#  'Well E8-3 1.tiff',
#  'Well E8-4 1.tiff']

# %%
image_list = []

for ix , i in enumerate(time_97):
    for filename in glob.glob(path + i): 
        im=cv2.imread(filename)

        image_list.append(im)

# %%
len(image_list)
# Out:
# 16

# %%
plt.imshow(image_list[10])

# %%
tot_dict_97 = {}

for idx, image in tqdm.tqdm(enumerate(image_list)):
    
    dict_1 = {}
    
    cx = []
    cy = []

    shifted = cv2.pyrMeanShiftFiltering(image, 20, 50)
    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    D = ndimage.distance_transform_edt(thresh)
    localMax = peak_local_max(D, indices=False, min_distance=20, labels=thresh)
    markers = ndimage.label(localMax, structure=np.ones((3, 3)))[0]
    labels = watershed(-D, markers, mask=thresh)
    
    

    for label in np.unique(labels):
        if label == 0:
            continue


        
        
        mask = np.zeros(gray.shape, dtype='uint8')
        mask[labels == label] = 255
        cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)
        ((x, y), r) = cv2.minEnclosingCircle(c)
        
        
        
        cx.append(int(x))
        cy.append(int(y))
        

        data = {'X':cx,'Y':cy}
        
        data = pd.DataFrame(data)

    
    dict_1[idx] = data
    
    tot_dict_97.update(dict_1)
# Out:
# 0it [00:00, ?it/s]
# 1it [00:04,  4.37s/it]
# 2it [00:09,  4.66s/it]
# 3it [00:13,  4.42s/it]
# 4it [00:18,  4.67s/it]
# 5it [00:23,  4.61s/it]
# 6it [00:28,  4.94s/it]
# 7it [00:35,  5.30s/it]
# 8it [00:40,  5.42s/it]
# 9it [00:47,  5.94s/it]
# 10it [00:54,  6.12s/it]
# 11it [01:03,  6.86s/it]
# 12it [01:10,  7.10s/it]
# 13it [01:18,  7.36s/it]
# 14it [01:25,  7.13s/it]
# 15it [01:32,  7.03s/it]
# 16it [01:38,  6.13s/it]
